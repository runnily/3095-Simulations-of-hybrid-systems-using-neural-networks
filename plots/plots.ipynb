# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

# %%
sns.set_theme()
data_df = pd.read_csv('../data/cooling.csv', usecols=[0,1,3], nrows=11)
preds_df = pd.read_csv('../data/preds/cooling.csv', usecols=[0,1], nrows=11)
sns.relplot(
    data=data_df, kind="line",
    x="x", y="y",
    palette='rocket', 
    #hue='state'style="state",markers=True
)

sns.relplot(
    data=preds_df, kind="line",
    x="time", y="temp",
    palette='rocket', 
    #hue='state'style="state",markers=True
)

# %%
df = pd.read_csv('../data/thermostat.csv', usecols=[0,1,3], nrows=11)
sns.relplot(
    data=df, kind="line",
    x="x", y="y",
    palette='rocket', 
    #hue='state'style="state",markers=True
)

# %%
df = pd.read_csv('../data/oscillate/oscillate.csv', usecols=[1,2], nrows=50)
sns.relplot(
    data=df, kind="line",
    x="x", y="y",
    palette='rocket', 
    #hue='state'style="state",markers=True
)

# %%
df = pd.read_csv('../data/oscillate/x_data.csv', usecols=[0,1], nrows=50)
sns.relplot(
    data=df, kind="line",
    x="time", y="x",
    palette='rocket', 
    #hue='state'style="state",markers=True
)

# %%
df = pd.read_csv('../data/oscillate/y_data.csv', usecols=[0,1], nrows=50)
sns.relplot(
    data=df, kind="line",
    x="time", y="y",
    palette='rocket', 
    #hue='state'style="state",markers=True
)
